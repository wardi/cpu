# %%
# %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
SZ = (20, 20)

# %%
#r = np.fromfunction(
#    lambda y, x: x + y * 5, SZ)
#r = np.arange(SZ[1])[None,:] + (np.arange(SZ[0]) * 4)[:,None]
X, Y = np.meshgrid(np.arange(SZ[1]), np.arange(SZ[0]))
r = X + Y * 4
#r
fig, ax = plt.subplots()
ax.imshow(r); None
#plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#h = np.sin(np.fromfunction(lambda y, x: np.hypot(9.5-x, 1.5-y), SZ))
h = np.sin(np.hypot(4.5-X, 12.5-Y))
fig, ax = plt.subplots()
ax.imshow(h)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#im = np.fromfunction(lambda y,x: np.sin(.9*(x+10)/(5+.5*np.cos(y))) * np.cos(2*(y)/(6+.9*np.sin(x))), (20,20))
X2, Y2 = np.meshgrid(np.arange(20), np.arange(20))
im = np.sin(.9*(X2+10)/(5+.5*np.cos(Y2))) * np.cos(2*Y2/(6+.9*np.sin(X2)))
fig, ax = plt.subplots()
ax.imshow(im)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
c = np.multiply(im, h)
fig, ax = plt.subplots()
ax.imshow(c)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
